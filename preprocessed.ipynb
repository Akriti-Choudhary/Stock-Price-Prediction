# %%
import os
import pandas as pd

# %%
directory_path = '/home/vivek/Desktop/mldatasets/datasets/'
print(directory_path)
# Out:
# /home/vivek/Desktop/mldatasets/datasets/

# %%
csv_files = [file for file in os.listdir(directory_path) if file.endswith('.csv')]

# %%
dataframes = []
for file in csv_files:
    file_path = os.path.join(directory_path, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)

# %%
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
df2 = pd.read_csv('stock_metadata.csv')

# %%
merged_df = pd.merge(combined_df, df2, on='Symbol', how='inner')

# %%
merged_df.head()
# Out:
#          Date      Symbol Series_x  Prev Close    Open   High     Low    Last  \
# 0  2008-05-26  BAJAJ-AUTO       EQ     2101.05  898.00  898.0  551.35  600.25
# 1  2008-05-27  BAJAJ-AUTO       EQ      604.75  624.70  639.0  580.30  595.50
# 2  2008-05-28  BAJAJ-AUTO       EQ      593.15  561.65  621.9  561.65  605.10
# 3  2008-05-29  BAJAJ-AUTO       EQ      608.15  619.40  619.4  576.00  600.00
# 4  2008-05-30  BAJAJ-AUTO       EQ      599.45  605.40  607.0  538.00  576.25
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  604.75  624.61  3972485  2.481245e+14     NaN           1202933.0
# 1  593.15  606.43  1751063  1.061901e+14     NaN            369389.0
# 2  608.15  608.75  1652355  1.005877e+14     NaN            898602.0
# 3  599.45  600.98   669269  4.022165e+13     NaN            449951.0
# 4  571.70  565.55  1262117  7.137937e+13     NaN            936432.0
#
#    %Deliverble     Company Name    Industry Series_y     ISIN Code
# 0       0.3028  Bajaj Auto Ltd.  AUTOMOBILE       EQ  INE917I01010
# 1       0.2110  Bajaj Auto Ltd.  AUTOMOBILE       EQ  INE917I01010
# 2       0.5438  Bajaj Auto Ltd.  AUTOMOBILE       EQ  INE917I01010
# 3       0.6723  Bajaj Auto Ltd.  AUTOMOBILE       EQ  INE917I01010
# 4       0.7420  Bajaj Auto Ltd.  AUTOMOBILE       EQ  INE917I01010

# %%
merged_df.drop(['Trades','Series_y', 'ISIN Code'], axis=1, inplace=True)

# %%
merged_df.head()
# Out:
#          Date      Symbol Series_x  Prev Close    Open   High     Low    Last  \
# 0  2008-05-26  BAJAJ-AUTO       EQ     2101.05  898.00  898.0  551.35  600.25
# 1  2008-05-27  BAJAJ-AUTO       EQ      604.75  624.70  639.0  580.30  595.50
# 2  2008-05-28  BAJAJ-AUTO       EQ      593.15  561.65  621.9  561.65  605.10
# 3  2008-05-29  BAJAJ-AUTO       EQ      608.15  619.40  619.4  576.00  600.00
# 4  2008-05-30  BAJAJ-AUTO       EQ      599.45  605.40  607.0  538.00  576.25
#
#     Close    VWAP   Volume      Turnover  Deliverable Volume  %Deliverble  \
# 0  604.75  624.61  3972485  2.481245e+14           1202933.0       0.3028
# 1  593.15  606.43  1751063  1.061901e+14            369389.0       0.2110
# 2  608.15  608.75  1652355  1.005877e+14            898602.0       0.5438
# 3  599.45  600.98   669269  4.022165e+13            449951.0       0.6723
# 4  571.70  565.55  1262117  7.137937e+13            936432.0       0.7420
#
#       Company Name    Industry
# 0  Bajaj Auto Ltd.  AUTOMOBILE
# 1  Bajaj Auto Ltd.  AUTOMOBILE
# 2  Bajaj Auto Ltd.  AUTOMOBILE
# 3  Bajaj Auto Ltd.  AUTOMOBILE
# 4  Bajaj Auto Ltd.  AUTOMOBILE

# %%
merged_df.drop(['Series_y'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 merged_df.drop(['Series_y'],axis=1,inplace=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Series_y'] not found in axis"

# %%
merged_df.head()
# Out:
#          Date      Symbol Series_x  Prev Close    Open   High     Low    Last  \
# 0  2008-05-26  BAJAJ-AUTO       EQ     2101.05  898.00  898.0  551.35  600.25
# 1  2008-05-27  BAJAJ-AUTO       EQ      604.75  624.70  639.0  580.30  595.50
# 2  2008-05-28  BAJAJ-AUTO       EQ      593.15  561.65  621.9  561.65  605.10
# 3  2008-05-29  BAJAJ-AUTO       EQ      608.15  619.40  619.4  576.00  600.00
# 4  2008-05-30  BAJAJ-AUTO       EQ      599.45  605.40  607.0  538.00  576.25
#
#     Close    VWAP   Volume      Turnover  Deliverable Volume  %Deliverble  \
# 0  604.75  624.61  3972485  2.481245e+14           1202933.0       0.3028
# 1  593.15  606.43  1751063  1.061901e+14            369389.0       0.2110
# 2  608.15  608.75  1652355  1.005877e+14            898602.0       0.5438
# 3  599.45  600.98   669269  4.022165e+13            449951.0       0.6723
# 4  571.70  565.55  1262117  7.137937e+13            936432.0       0.7420
#
#       Company Name    Industry
# 0  Bajaj Auto Ltd.  AUTOMOBILE
# 1  Bajaj Auto Ltd.  AUTOMOBILE
# 2  Bajaj Auto Ltd.  AUTOMOBILE
# 3  Bajaj Auto Ltd.  AUTOMOBILE
# 4  Bajaj Auto Ltd.  AUTOMOBILE

# %%
merged_df.to_csv('final_merged.csv')
